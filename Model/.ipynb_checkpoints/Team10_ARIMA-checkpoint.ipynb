# %% [markdown]
# # 1. BTC/USD Dataset (Data split 7:3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Dataset/BTC_USD-Binance-Historical-Data_New.csv')
df = df.sort_index(ascending=False)
df['Date'] = pd.to_datetime(df['Date'])
df['Price'] = pd.to_numeric(df['Price'].str.replace(',', ''))
df.set_index('Date',inplace=True)
df = df[['Price']]

# %%
train_size = int(0.7 * len(df))
test_size = len(df) - train_size
train_data = df[:train_size]
test_data = df[train_size:]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def test_stationarity(variable):
    result=adfuller(variable)
    labels = ['t-statistics', 'p-value', 'lags_used', 'number of observations used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Data is stationary")
    else:
        print("Data is non-stationary ")

# %%
test_stationarity(train_data['Price'])
# Out:
# t-statistics : -1.494960941240968
# p-value : 0.536002600115062
# lags_used : 12
# number of observations used : 1331
# Data is non-stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['Price'])
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11088\220069074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)

# %%
test_stationarity(train_data['First Difference'].dropna())
# Out:
# t-statistics : -10.45820391229056
# p-value : 1.3808641939967768e-18
# lags_used : 11
# number of observations used : 1331
# Data is stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['First Difference'])
# Out:
# <Axes: xlabel='Date', ylabel='First Difference'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_pacf(train_data['First Difference'].dropna(),lags=20)

# %%
plot_acf(train_data['First Difference'].dropna(),lags=20)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(train_data['Price'], order = (9,1,9))
model_fit = model.fit()
model_fit.summary()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1344
# Model:                 ARIMA(9, 1, 9)   Log Likelihood              -11354.858
# Date:                Wed, 05 Jun 2024   AIC                          22747.716
# Time:                        10:14:45   BIC                          22846.566
# Sample:                    03-01-2019   HQIC                         22784.745
#                          - 11-03-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1384      0.413      0.335      0.737      -0.670       0.947
# ar.L2          0.1378      0.269      0.513      0.608      -0.389       0.664
# ar.L3         -0.3701      0.109     -3.389      0.001      -0.584      -0.156
# ar.L4          0.5993      0.146      4.097      0.000       0.313       0.886
# ar.L5         -0.0193      0.342     -0.056      0.955      -0.690       0.652
# ar.L6         -0.5051      0.145     -3.488      0.000      -0.789      -0.221
# ar.L7          0.4130      0.151      2.743      0.006       0.118       0.708
# ar.L8         -0.4124      0.254     -1.626      0.104      -0.909       0.085
# ar.L9         -0.2719      0.315     -0.863      0.388      -0.889       0.345
# ma.L1         -0.1656      0.405     -0.409      0.683      -0.959       0.628
# ma.L2         -0.1309      0.280     -0.467      0.640      -0.680       0.418
# ma.L3          0.3915      0.115      3.395      0.001       0.165       0.618
# ma.L4         -0.5733      0.134     -4.279      0.000      -0.836      -0.311
# ma.L5          0.0336      0.324      0.104      0.918      -0.602       0.669
# ma.L6          0.5386      0.151      3.566      0.000       0.243       0.835
# ma.L7         -0.4963      0.149     -3.323      0.001      -0.789      -0.204
# ma.L8          0.4197      0.280      1.499      0.134      -0.129       0.968
# ma.L9          0.3498      0.331      1.055      0.291      -0.300       0.999
# sigma2      1.342e+06   2.91e+04     46.062      0.000    1.29e+06     1.4e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              2135.55
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):              13.14   Skew:                            -0.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.17
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_prediction = model_fit.forecast(steps=len(test_data))
frame = {'Price':test_prediction[0:]}
test_prediction_df = pd.DataFrame(frame)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
y_test = np.array(test_data['Price'])
y_pred = np.array(test_prediction_df['Price'])

mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print("MAPE:", mape )
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# MAPE: 36.855363626082195
# RMSE: 22094.05851574523
# MAE: 16069.352506697036

# %%
last_date = df.index[-1]
future_index = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=90)

# %%
future_prediction = model_fit.forecast(steps=len(test_data)+90)

# %%
frame = {'Price':future_prediction[0:]}
future_prediction_df = pd.DataFrame(frame)

# %%
next60days_df = future_prediction_df[-90:]
next60days_df = next60days_df[:60]
next60days_index = future_index[-90:]
next60days_index = next60days_index[:60]

next30days_df = future_prediction_df[-90:]
next30days_df = next30days_df[:30]
next30days_index = future_index[-90:]
next30days_index = next30days_index[:30]

# %%
sns.lineplot(data=train_data, x=train_data.index, y=train_data['Price'],label='Train')
sns.lineplot(data=test_data, x=test_data.index, y=test_data['Price'],label='Test')
sns.lineplot(data=test_data, x=test_data.index, y=test_prediction,label='Predict')
sns.lineplot(data=future_prediction_df[-90:], x=future_index[:90], y=future_prediction_df['Price'][-90:],label='Predict next 90 days')
sns.lineplot(data=next60days_df, x=next60days_index, y=next60days_df['Price'],label='Predict next 60 days')
sns.lineplot(data=next30days_df, x=next30days_index, y=next30days_df['Price'],label='Predict next 30 days')
plt.title('Bitcoin Time Series Forecasting')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # 2. ETH/USD Dataset (Data split 7:3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Dataset/ETH_USD-Binance-Historical-Data-1_New.csv')
df = df.sort_index(ascending=False)
df['Date'] = pd.to_datetime(df['Date'])
df['Price'] = pd.to_numeric(df['Price'].str.replace(',', ''))
df.set_index('Date',inplace=True)
df = df[['Price']]

# %%
train_size = int(0.7 * len(df))
test_size = len(df) - train_size
train_data = df[:train_size]
test_data = df[train_size:]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def test_stationarity(variable):
    result=adfuller(variable)
    labels = ['t-statistics', 'p-value', 'lags_used', 'number of observations used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Data is stationary")
    else:
        print("Data is non-stationary ")

# %%
test_stationarity(train_data['Price'])
# Out:
# t-statistics : -1.3767031021035137
# p-value : 0.5933925920323656
# lags_used : 17
# number of observations used : 1326
# Data is non-stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['Price'])
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11088\220069074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)

# %%
test_stationarity(train_data['First Difference'].dropna())
# Out:
# t-statistics : -9.065563577369492
# p-value : 4.442522869909455e-15
# lags_used : 16
# number of observations used : 1326
# Data is stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['First Difference'])
# Out:
# <Axes: xlabel='Date', ylabel='First Difference'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_pacf(train_data['First Difference'].dropna(),lags=20)

# %%
plot_acf(train_data['First Difference'].dropna(),lags=20)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(train_data['Price'], order = (6,1,6))
model_fit = model.fit()
model_fit.summary()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1344
# Model:                 ARIMA(6, 1, 6)   Log Likelihood               -7944.602
# Date:                Wed, 05 Jun 2024   AIC                          15915.203
# Time:                        10:17:43   BIC                          15982.838
# Sample:                    03-01-2019   HQIC                         15940.539
#                          - 11-03-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5559      0.235     -2.364      0.018      -1.017      -0.095
# ar.L2          0.4868      0.334      1.459      0.145      -0.167       1.141
# ar.L3          0.6735      0.185      3.646      0.000       0.311       1.035
# ar.L4          0.5721      0.132      4.328      0.000       0.313       0.831
# ar.L5         -0.2634      0.241     -1.091      0.275      -0.737       0.210
# ar.L6         -0.6777      0.167     -4.070      0.000      -1.004      -0.351
# ma.L1          0.4975      0.232      2.146      0.032       0.043       0.952
# ma.L2         -0.4819      0.317     -1.519      0.129      -1.104       0.140
# ma.L3         -0.5945      0.176     -3.371      0.001      -0.940      -0.249
# ma.L4         -0.5152      0.122     -4.237      0.000      -0.753      -0.277
# ma.L5          0.2066      0.214      0.966      0.334      -0.212       0.626
# ma.L6          0.6902      0.161      4.281      0.000       0.374       1.006
# sigma2      8255.5201    151.955     54.329      0.000    7957.694    8553.346
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):              7388.74
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):             146.84   Skew:                            -0.69
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_prediction = model_fit.forecast(steps=len(test_data))
frame = {'Price':test_prediction[0:]}
test_prediction_df = pd.DataFrame(frame)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
y_test = np.array(test_data['Price'])
y_pred = np.array(test_prediction_df['Price'])

mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print("MAPE:", mape )
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# MAPE: 24.795868894851957
# RMSE: 887.161058541895
# MAE: 618.8091965403019

# %%
last_date = df.index[-1]
future_index = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=90)

# %%
future_prediction = model_fit.forecast(steps=len(test_data)+90)

# %%
frame = {'Price':future_prediction[0:]}
future_prediction_df = pd.DataFrame(frame)

# %%
next60days_df = future_prediction_df[-90:]
next60days_df = next60days_df[:60]
next60days_index = future_index[-90:]
next60days_index = next60days_index[:60]

next30days_df = future_prediction_df[-90:]
next30days_df = next30days_df[:30]
next30days_index = future_index[-90:]
next30days_index = next30days_index[:30]

# %%
sns.lineplot(data=train_data, x=train_data.index, y=train_data['Price'],label='Train')
sns.lineplot(data=test_data, x=test_data.index, y=test_data['Price'],label='Test')
sns.lineplot(data=test_data, x=test_data.index, y=test_prediction,label='Predict')
sns.lineplot(data=future_prediction_df[-90:], x=future_index[:90], y=future_prediction_df['Price'][-90:],label='Predict next 90 days')
sns.lineplot(data=next60days_df, x=next60days_index, y=next60days_df['Price'],label='Predict next 60 days')
sns.lineplot(data=next30days_df, x=next30days_index, y=next30days_df['Price'],label='Predict next 30 days')
plt.title('Ethereum Time Series Forecasting')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # 3. BNB/USD Dataset (Data split 7:3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Dataset/BNB_USD-Binance-Historical-Data_New.csv')
df = df.sort_index(ascending=False)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)
df = df[['Price']]

# %%
train_size = int(0.7 * len(df))
test_size = len(df) - train_size
train_data = df[:train_size]
test_data = df[train_size:]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def test_stationarity(variable):
    result=adfuller(variable)
    labels = ['t-statistics', 'p-value', 'lags_used', 'number of observations used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Data is stationary")
    else:
        print("Data is non-stationary ")

# %%
test_stationarity(train_data['Price'])
# Out:
# t-statistics : -1.4582790920399227
# p-value : 0.5540399614490752
# lags_used : 21
# number of observations used : 1322
# Data is non-stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['Price'])
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11088\220069074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)

# %%
test_stationarity(train_data['First Difference'].dropna())
# Out:
# t-statistics : -7.153135716380055
# p-value : 3.103630720137591e-10
# lags_used : 23
# number of observations used : 1319
# Data is stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['First Difference'])
# Out:
# <Axes: xlabel='Date', ylabel='First Difference'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_pacf(train_data['First Difference'].dropna(),lags=20)

# %%
plot_acf(train_data['First Difference'].dropna(),lags=20)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(train_data['Price'], order = (5,1,5))
model_fit = model.fit()
model_fit.summary()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1344
# Model:                 ARIMA(5, 1, 5)   Log Likelihood               -5465.637
# Date:                Wed, 05 Jun 2024   AIC                          10953.273
# Time:                        10:53:20   BIC                          11010.502
# Sample:                    03-01-2019   HQIC                         10974.711
#                          - 11-03-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2314      0.060      3.881      0.000       0.115       0.348
# ar.L2         -0.5232      0.065     -8.024      0.000      -0.651      -0.395
# ar.L3         -0.0382      0.080     -0.479      0.632      -0.194       0.118
# ar.L4         -0.2715      0.053     -5.114      0.000      -0.376      -0.167
# ar.L5         -0.6839      0.052    -13.224      0.000      -0.785      -0.583
# ma.L1         -0.3696      0.065     -5.704      0.000      -0.497      -0.243
# ma.L2          0.6657      0.074      9.037      0.000       0.521       0.810
# ma.L3         -0.0608      0.096     -0.632      0.527      -0.249       0.128
# ma.L4          0.3240      0.069      4.700      0.000       0.189       0.459
# ma.L5          0.5816      0.062      9.450      0.000       0.461       0.702
# sigma2       197.4901      2.686     73.529      0.000     192.226     202.754
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             31888.07
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):             236.58   Skew:                            -0.51
# Prob(H) (two-sided):                  0.00   Kurtosis:                        26.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_prediction = model_fit.forecast(steps=len(test_data))
frame = {'Price':test_prediction[0:]}
test_prediction_df = pd.DataFrame(frame)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
y_test = np.array(test_data['Price'])
y_pred = np.array(test_prediction_df['Price'])

mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print("MAPE:", mape )
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# MAPE: 26.331761575285604
# RMSE: 116.76239135744133
# MAE: 86.35333730326505

# %%
last_date = df.index[-1]
future_index = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=90)

# %%
future_prediction = model_fit.forecast(steps=len(test_data)+90)

# %%
frame = {'Price':future_prediction[0:]}
future_prediction_df = pd.DataFrame(frame)

# %%
next60days_df = future_prediction_df[-90:]
next60days_df = next60days_df[:60]
next60days_index = future_index[-90:]
next60days_index = next60days_index[:60]

next30days_df = future_prediction_df[-90:]
next30days_df = next30days_df[:30]
next30days_index = future_index[-90:]
next30days_index = next30days_index[:30]

# %%
sns.lineplot(data=train_data, x=train_data.index, y=train_data['Price'],label='Train')
sns.lineplot(data=test_data, x=test_data.index, y=test_data['Price'],label='Test')
sns.lineplot(data=test_data, x=test_data.index, y=test_prediction,label='Predict')
sns.lineplot(data=future_prediction_df[-90:], x=future_index[:90], y=future_prediction_df['Price'][-90:],label='Predict next 90 days')
sns.lineplot(data=next60days_df, x=next60days_index, y=next60days_df['Price'],label='Predict next 60 days')
sns.lineplot(data=next30days_df, x=next30days_index, y=next30days_df['Price'],label='Predict next 30 days')
plt.title('BNB Time Series Forecasting')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # 4. BTC/USD Dataset (Data split 8:2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Dataset/BTC_USD-Binance-Historical-Data_New.csv')
df = df.sort_index(ascending=False)
df['Date'] = pd.to_datetime(df['Date'])
df['Price'] = pd.to_numeric(df['Price'].str.replace(',', ''))
df.set_index('Date',inplace=True)
df = df[['Price']]

# %%
train_size = int(0.8 * len(df))
test_size = len(df) - train_size
train_data = df[:train_size]
test_data = df[train_size:]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def test_stationarity(variable):
    result=adfuller(variable)
    labels = ['t-statistics', 'p-value', 'lags_used', 'number of observations used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Data is stationary")
    else:
        print("Data is non-stationary ")

# %%
test_stationarity(train_data['Price'])
# Out:
# t-statistics : -1.6399506303086384
# p-value : 0.46228659004370704
# lags_used : 9
# number of observations used : 1526
# Data is non-stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['Price'])
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11088\220069074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)

# %%
test_stationarity(train_data['First Difference'].dropna())
# Out:
# t-statistics : -12.45707789104468
# p-value : 3.471689650111752e-23
# lags_used : 8
# number of observations used : 1526
# Data is stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['First Difference'])
# Out:
# <Axes: xlabel='Date', ylabel='First Difference'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_pacf(train_data['First Difference'].dropna(),lags=20)

# %%
plot_acf(train_data['First Difference'].dropna(),lags=20)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(train_data['Price'], order = (9,1,9))
model_fit = model.fit()
model_fit.summary()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1536
# Model:                 ARIMA(9, 1, 9)   Log Likelihood              -12910.203
# Date:                Wed, 05 Jun 2024   AIC                          25858.406
# Time:                        10:56:44   BIC                          25959.795
# Sample:                    03-01-2019   HQIC                         25896.134
#                          - 05-14-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2415      0.393      0.615      0.539      -0.528       1.011
# ar.L2          0.2670      0.288      0.926      0.355      -0.298       0.832
# ar.L3         -0.3560      0.114     -3.114      0.002      -0.580      -0.132
# ar.L4          0.5337      0.164      3.263      0.001       0.213       0.854
# ar.L5         -0.0965      0.298     -0.324      0.746      -0.681       0.488
# ar.L6         -0.5599      0.153     -3.671      0.000      -0.859      -0.261
# ar.L7          0.4486      0.151      2.979      0.003       0.153       0.744
# ar.L8         -0.3775      0.265     -1.423      0.155      -0.897       0.142
# ar.L9         -0.2577      0.309     -0.835      0.404      -0.863       0.347
# ma.L1         -0.2648      0.386     -0.686      0.493      -1.022       0.492
# ma.L2         -0.2446      0.298     -0.820      0.412      -0.829       0.340
# ma.L3          0.3847      0.119      3.238      0.001       0.152       0.618
# ma.L4         -0.5255      0.151     -3.469      0.001      -0.822      -0.229
# ma.L5          0.1091      0.290      0.376      0.707      -0.459       0.677
# ma.L6          0.5902      0.162      3.634      0.000       0.272       0.908
# ma.L7         -0.5412      0.149     -3.644      0.000      -0.832      -0.250
# ma.L8          0.3906      0.292      1.336      0.182      -0.182       0.964
# ma.L9          0.3354      0.330      1.015      0.310      -0.312       0.983
# sigma2      1.223e+06   2.37e+04     51.678      0.000    1.18e+06    1.27e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):              2912.55
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.05   Skew:                            -0.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_prediction = model_fit.forecast(steps=len(test_data))
frame = {'Price':test_prediction[0:]}
test_prediction_df = pd.DataFrame(frame)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
y_test = np.array(test_data['Price'])
y_pred = np.array(test_prediction_df['Price'])

mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print("MAPE:", mape )
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# MAPE: 28.620241024039387
# RMSE: 21759.273620644257
# MAE: 15439.402257617156

# %%
last_date = df.index[-1]
future_index = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=90)

# %%
future_prediction = model_fit.forecast(steps=len(test_data)+90)

# %%
frame = {'Price':future_prediction[0:]}
future_prediction_df = pd.DataFrame(frame)

# %%
next60days_df = future_prediction_df[-90:]
next60days_df = next60days_df[:60]
next60days_index = future_index[-90:]
next60days_index = next60days_index[:60]

next30days_df = future_prediction_df[-90:]
next30days_df = next30days_df[:30]
next30days_index = future_index[-90:]
next30days_index = next30days_index[:30]

# %%
sns.lineplot(data=train_data, x=train_data.index, y=train_data['Price'],label='Train')
sns.lineplot(data=test_data, x=test_data.index, y=test_data['Price'],label='Test')
sns.lineplot(data=test_data, x=test_data.index, y=test_prediction,label='Predict')
sns.lineplot(data=future_prediction_df[-90:], x=future_index[:90], y=future_prediction_df['Price'][-90:],label='Predict next 90 days')
sns.lineplot(data=next60days_df, x=next60days_index, y=next60days_df['Price'],label='Predict next 60 days')
sns.lineplot(data=next30days_df, x=next30days_index, y=next30days_df['Price'],label='Predict next 30 days')
plt.title('Bitcoin Time Series Forecasting')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # 5. ETH/USD Dataset (Data split 8:2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Dataset/ETH_USD-Binance-Historical-Data-1_New.csv')
df = df.sort_index(ascending=False)
df['Date'] = pd.to_datetime(df['Date'])
df['Price'] = pd.to_numeric(df['Price'].str.replace(',', ''))
df.set_index('Date',inplace=True)
df = df[['Price']]

# %%
train_size = int(0.8 * len(df))
test_size = len(df) - train_size
train_data = df[:train_size]
test_data = df[train_size:]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def test_stationarity(variable):
    result=adfuller(variable)
    labels = ['t-statistics', 'p-value', 'lags_used', 'number of observations used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Data is stationary")
    else:
        print("Data is non-stationary ")

# %%
test_stationarity(train_data['Price'])
# Out:
# t-statistics : -1.4684104797865103
# p-value : 0.5490763572134386
# lags_used : 17
# number of observations used : 1518
# Data is non-stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['Price'])
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11088\220069074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)

# %%
test_stationarity(train_data['First Difference'].dropna())
# Out:
# t-statistics : -9.790862558602406
# p-value : 6.359115703117336e-17
# lags_used : 16
# number of observations used : 1518
# Data is stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['First Difference'])
# Out:
# <Axes: xlabel='Date', ylabel='First Difference'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_pacf(train_data['First Difference'].dropna(),lags=20)

# %%
plot_acf(train_data['First Difference'].dropna(),lags=20)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(train_data['Price'], order = (6,1,6))
model_fit = model.fit()
model_fit.summary()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1536
# Model:                 ARIMA(6, 1, 6)   Log Likelihood               -9014.308
# Date:                Wed, 05 Jun 2024   AIC                          18054.617
# Time:                        11:02:48   BIC                          18123.988
# Sample:                    03-01-2019   HQIC                         18080.430
#                          - 05-14-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5489      0.145     -3.789      0.000      -0.833      -0.265
# ar.L2          0.5064      0.204      2.479      0.013       0.106       0.907
# ar.L3          0.6513      0.125      5.220      0.000       0.407       0.896
# ar.L4          0.5044      0.108      4.666      0.000       0.292       0.716
# ar.L5         -0.3161      0.163     -1.938      0.053      -0.636       0.004
# ar.L6         -0.7006      0.109     -6.418      0.000      -0.915      -0.487
# ma.L1          0.4812      0.142      3.396      0.001       0.203       0.759
# ma.L2         -0.5093      0.191     -2.665      0.008      -0.884      -0.135
# ma.L3         -0.5713      0.117     -4.885      0.000      -0.800      -0.342
# ma.L4         -0.4494      0.101     -4.470      0.000      -0.646      -0.252
# ma.L5          0.2632      0.146      1.802      0.072      -0.023       0.549
# ma.L6          0.7164      0.105      6.851      0.000       0.511       0.921
# sigma2      7551.2501    126.091     59.887      0.000    7304.117    7798.383
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              9614.69
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):              72.57   Skew:                            -0.72
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_prediction = model_fit.forecast(steps=len(test_data))
frame = {'Price':test_prediction[0:]}
test_prediction_df = pd.DataFrame(frame)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
y_test = np.array(test_data['Price'])
y_pred = np.array(test_prediction_df['Price'])

mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print("MAPE:", mape )
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# MAPE: 20.993432186903686
# RMSE: 884.4953419697612
# MAE: 607.3062083768195

# %%
last_date = df.index[-1]
future_index = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=90)

# %%
future_prediction = model_fit.forecast(steps=len(test_data)+90)

# %%
frame = {'Price':future_prediction[0:]}
future_prediction_df = pd.DataFrame(frame)

# %%
next60days_df = future_prediction_df[-90:]
next60days_df = next60days_df[:60]
next60days_index = future_index[-90:]
next60days_index = next60days_index[:60]

next30days_df = future_prediction_df[-90:]
next30days_df = next30days_df[:30]
next30days_index = future_index[-90:]
next30days_index = next30days_index[:30]

# %%
sns.lineplot(data=train_data, x=train_data.index, y=train_data['Price'],label='Train')
sns.lineplot(data=test_data, x=test_data.index, y=test_data['Price'],label='Test')
sns.lineplot(data=test_data, x=test_data.index, y=test_prediction,label='Predict')
sns.lineplot(data=future_prediction_df[-90:], x=future_index[:90], y=future_prediction_df['Price'][-90:],label='Predict next 90 days')
sns.lineplot(data=next60days_df, x=next60days_index, y=next60days_df['Price'],label='Predict next 60 days')
sns.lineplot(data=next30days_df, x=next30days_index, y=next30days_df['Price'],label='Predict next 30 days')
plt.title('Ethereum Time Series Forecasting')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # 6. BNB/USD Dataset (Data split 8:2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Dataset/BNB_USD-Binance-Historical-Data_New.csv')
df = df.sort_index(ascending=False)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)
df = df[['Price']]

# %%
train_size = int(0.8 * len(df))
test_size = len(df) - train_size
train_data = df[:train_size]
test_data = df[train_size:]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def test_stationarity(variable):
    result=adfuller(variable)
    labels = ['t-statistics', 'p-value', 'lags_used', 'number of observations used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Data is stationary")
    else:
        print("Data is non-stationary ")

# %%
test_stationarity(train_data['Price'])
# Out:
# t-statistics : -1.5902395585045759
# p-value : 0.4884946460830962
# lags_used : 24
# number of observations used : 1511
# Data is non-stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['Price'])
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11088\220069074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)

# %%
test_stationarity(train_data['First Difference'].dropna())
# Out:
# t-statistics : -7.309134500732602
# p-value : 1.2780017394284347e-10
# lags_used : 24
# number of observations used : 1510
# Data is stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['First Difference'])
# Out:
# <Axes: xlabel='Date', ylabel='First Difference'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_pacf(train_data['First Difference'].dropna(),lags=20)

# %%
plot_acf(train_data['First Difference'].dropna(),lags=20)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(train_data['Price'], order = (1,1,1))
model_fit = model.fit()
model_fit.summary()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1536
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -6220.838
# Date:                Wed, 05 Jun 2024   AIC                          12447.676
# Time:                        11:07:27   BIC                          12463.685
# Sample:                    03-01-2019   HQIC                         12453.633
#                          - 05-14-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4743      0.066     -7.158      0.000      -0.604      -0.344
# ma.L1          0.3371      0.071      4.728      0.000       0.197       0.477
# sigma2       193.7295      2.055     94.287      0.000     189.702     197.757
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             47776.45
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):             142.97   Skew:                            -0.60
# Prob(H) (two-sided):                  0.00   Kurtosis:                        30.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_prediction = model_fit.forecast(steps=len(test_data))
frame = {'Price':test_prediction[0:]}
test_prediction_df = pd.DataFrame(frame)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
y_test = np.array(test_data['Price'])
y_pred = np.array(test_prediction_df['Price'])

mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print("MAPE:", mape )
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# MAPE: 30.3460487737405
# RMSE: 141.8474572306864
# MAE: 107.94584289128949

# %%
last_date = df.index[-1]
future_index = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=90)

# %%
future_prediction = model_fit.forecast(steps=len(test_data)+90)

# %%
frame = {'Price':future_prediction[0:]}
future_prediction_df = pd.DataFrame(frame)

# %%
next60days_df = future_prediction_df[-90:]
next60days_df = next60days_df[:60]
next60days_index = future_index[-90:]
next60days_index = next60days_index[:60]

next30days_df = future_prediction_df[-90:]
next30days_df = next30days_df[:30]
next30days_index = future_index[-90:]
next30days_index = next30days_index[:30]

# %%
sns.lineplot(data=train_data, x=train_data.index, y=train_data['Price'],label='Train')
sns.lineplot(data=test_data, x=test_data.index, y=test_data['Price'],label='Test')
sns.lineplot(data=test_data, x=test_data.index, y=test_prediction,label='Predict')
sns.lineplot(data=future_prediction_df[-90:], x=future_index[:90], y=future_prediction_df['Price'][-90:],label='Predict next 90 days')
sns.lineplot(data=next60days_df, x=next60days_index, y=next60days_df['Price'],label='Predict next 60 days')
sns.lineplot(data=next30days_df, x=next30days_index, y=next30days_df['Price'],label='Predict next 30 days')
plt.title('BNB Time Series Forecasting')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # 7. BTC/USD Dataset (Data split 9:1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Dataset/BTC_USD-Binance-Historical-Data_New.csv')
df = df.sort_index(ascending=False)
df['Date'] = pd.to_datetime(df['Date'])
df['Price'] = pd.to_numeric(df['Price'].str.replace(',', ''))
df.set_index('Date',inplace=True)
df = df[['Price']]

# %%
train_size = int(0.9 * len(df))
test_size = len(df) - train_size
train_data = df[:train_size]
test_data = df[train_size:]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def test_stationarity(variable):
    result=adfuller(variable)
    labels = ['t-statistics', 'p-value', 'lags_used', 'number of observations used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Data is stationary")
    else:
        print("Data is non-stationary ")

# %%
test_stationarity(train_data['Price'])
# Out:
# t-statistics : -1.6383865615943773
# p-value : 0.4631039851824099
# lags_used : 12
# number of observations used : 1715
# Data is non-stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['Price'])
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11088\220069074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)

# %%
test_stationarity(train_data['First Difference'].dropna())
# Out:
# t-statistics : -11.903552057842324
# p-value : 5.503144573449609e-22
# lags_used : 11
# number of observations used : 1715
# Data is stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['First Difference'])
# Out:
# <Axes: xlabel='Date', ylabel='First Difference'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_pacf(train_data['First Difference'].dropna(),lags=20)

# %%
plot_acf(train_data['First Difference'].dropna(),lags=20)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(train_data['Price'], order = (9,1,9))
model_fit = model.fit()
model_fit.summary()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1728
# Model:                 ARIMA(9, 1, 9)   Log Likelihood              -14468.134
# Date:                Wed, 05 Jun 2024   AIC                          28974.268
# Time:                        11:14:43   BIC                          29077.897
# Sample:                    03-01-2019   HQIC                         29012.601
#                          - 11-22-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3486      0.889      0.392      0.695      -1.394       2.092
# ar.L2          0.1316      0.573      0.230      0.818      -0.991       1.254
# ar.L3         -0.3864      0.098     -3.941      0.000      -0.579      -0.194
# ar.L4          0.6533      0.357      1.832      0.067      -0.046       1.352
# ar.L5         -0.1522      0.717     -0.212      0.832      -1.558       1.254
# ar.L6         -0.4689      0.293     -1.600      0.110      -1.043       0.105
# ar.L7          0.5792      0.327      1.771      0.077      -0.062       1.220
# ar.L8         -0.4919      0.623     -0.790      0.430      -1.713       0.729
# ar.L9         -0.1450      0.642     -0.226      0.821      -1.404       1.114
# ma.L1         -0.3877      0.884     -0.439      0.661      -2.120       1.345
# ma.L2         -0.0945      0.609     -0.155      0.877      -1.289       1.100
# ma.L3          0.4090      0.121      3.370      0.001       0.171       0.647
# ma.L4         -0.6654      0.350     -1.902      0.057      -1.351       0.020
# ma.L5          0.2106      0.726      0.290      0.772      -1.212       1.633
# ma.L6          0.4590      0.358      1.284      0.199      -0.242       1.160
# ma.L7         -0.6504      0.290     -2.240      0.025      -1.220      -0.081
# ma.L8          0.5290      0.670      0.789      0.430      -0.785       1.843
# ma.L9          0.1836      0.691      0.266      0.791      -1.171       1.538
# sigma2      1.126e+06    1.9e+04     59.433      0.000    1.09e+06    1.16e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              4208.43
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.22   Skew:                            -0.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_prediction = model_fit.forecast(steps=len(test_data))
frame = {'Price':test_prediction[0:]}
test_prediction_df = pd.DataFrame(frame)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
y_test = np.array(test_data['Price'])
y_pred = np.array(test_prediction_df['Price'])

mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print("MAPE:", mape )
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# MAPE: 28.96264043794568
# RMSE: 21255.138494753195
# MAE: 17740.84297230208

# %%
last_date = df.index[-1]
future_index = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=90)

# %%
future_prediction = model_fit.forecast(steps=len(test_data)+90)

# %%
frame = {'Price':future_prediction[0:]}
future_prediction_df = pd.DataFrame(frame)

# %%
next60days_df = future_prediction_df[-90:]
next60days_df = next60days_df[:60]
next60days_index = future_index[-90:]
next60days_index = next60days_index[:60]

next30days_df = future_prediction_df[-90:]
next30days_df = next30days_df[:30]
next30days_index = future_index[-90:]
next30days_index = next30days_index[:30]

# %%
sns.lineplot(data=train_data, x=train_data.index, y=train_data['Price'],label='Train')
sns.lineplot(data=test_data, x=test_data.index, y=test_data['Price'],label='Test')
sns.lineplot(data=test_data, x=test_data.index, y=test_prediction,label='Predict')
sns.lineplot(data=future_prediction_df[-90:], x=future_index[:90], y=future_prediction_df['Price'][-90:],label='Predict next 90 days')
sns.lineplot(data=next60days_df, x=next60days_index, y=next60days_df['Price'],label='Predict next 60 days')
sns.lineplot(data=next30days_df, x=next30days_index, y=next30days_df['Price'],label='Predict next 30 days')
plt.title('Bitcoin Time Series Forecasting')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # 8. ETH/USD Dataset (Data split 9:1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Dataset/ETH_USD-Binance-Historical-Data-1_New.csv')
df = df.sort_index(ascending=False)
df['Date'] = pd.to_datetime(df['Date'])
df['Price'] = pd.to_numeric(df['Price'].str.replace(',', ''))
df.set_index('Date',inplace=True)
df = df[['Price']]

# %%
train_size = int(0.9 * len(df))
test_size = len(df) - train_size
train_data = df[:train_size]
test_data = df[train_size:]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def test_stationarity(variable):
    result=adfuller(variable)
    labels = ['t-statistics', 'p-value', 'lags_used', 'number of observations used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Data is stationary")
    else:
        print("Data is non-stationary ")

# %%
test_stationarity(train_data['Price'])
# Out:
# t-statistics : -1.54829210694358
# p-value : 0.5095011982270166
# lags_used : 17
# number of observations used : 1710
# Data is non-stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['Price'])
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11088\220069074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)

# %%
test_stationarity(train_data['First Difference'].dropna())
# Out:
# t-statistics : -10.396333420706814
# p-value : 1.960852477601676e-18
# lags_used : 16
# number of observations used : 1710
# Data is stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['First Difference'])
# Out:
# <Axes: xlabel='Date', ylabel='First Difference'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_pacf(train_data['First Difference'].dropna(),lags=20)

# %%
plot_acf(train_data['First Difference'].dropna(),lags=20)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(train_data['Price'], order = (6,1,6))
model_fit = model.fit()
model_fit.summary()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1728
# Model:                 ARIMA(6, 1, 6)   Log Likelihood              -10062.530
# Date:                Wed, 05 Jun 2024   AIC                          20151.059
# Time:                        11:21:09   BIC                          20221.963
# Sample:                    03-01-2019   HQIC                         20177.287
#                          - 11-22-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5699      0.198     -2.882      0.004      -0.957      -0.182
# ar.L2          0.4754      0.280      1.697      0.090      -0.074       1.025
# ar.L3          0.6515      0.155      4.206      0.000       0.348       0.955
# ar.L4          0.5376      0.122      4.399      0.000       0.298       0.777
# ar.L5         -0.2628      0.209     -1.259      0.208      -0.672       0.146
# ar.L6         -0.6612      0.140     -4.715      0.000      -0.936      -0.386
# ma.L1          0.5030      0.195      2.585      0.010       0.122       0.884
# ma.L2         -0.4780      0.265     -1.807      0.071      -0.996       0.040
# ma.L3         -0.5685      0.145     -3.913      0.000      -0.853      -0.284
# ma.L4         -0.4794      0.112     -4.270      0.000      -0.699      -0.259
# ma.L5          0.2084      0.185      1.127      0.260      -0.154       0.571
# ma.L6          0.6746      0.135      4.993      0.000       0.410       0.939
# sigma2      6875.4717    103.862     66.198      0.000    6671.905    7079.038
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):             12864.30
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):              28.58   Skew:                            -0.72
# Prob(H) (two-sided):                  0.00   Kurtosis:                        16.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_prediction = model_fit.forecast(steps=len(test_data))
frame = {'Price':test_prediction[0:]}
test_prediction_df = pd.DataFrame(frame)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
y_test = np.array(test_data['Price'])
y_pred = np.array(test_prediction_df['Price'])

mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print("MAPE:", mape )
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# MAPE: 26.165394353219167
# RMSE: 1020.5151993605783
# MAE: 841.5111637510345

# %%
last_date = df.index[-1]
future_index = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=90)

# %%
future_prediction = model_fit.forecast(steps=len(test_data)+90)

# %%
frame = {'Price':future_prediction[0:]}
future_prediction_df = pd.DataFrame(frame)

# %%
next60days_df = future_prediction_df[-90:]
next60days_df = next60days_df[:60]
next60days_index = future_index[-90:]
next60days_index = next60days_index[:60]

next30days_df = future_prediction_df[-90:]
next30days_df = next30days_df[:30]
next30days_index = future_index[-90:]
next30days_index = next30days_index[:30]

# %%
sns.lineplot(data=train_data, x=train_data.index, y=train_data['Price'],label='Train')
sns.lineplot(data=test_data, x=test_data.index, y=test_data['Price'],label='Test')
sns.lineplot(data=test_data, x=test_data.index, y=test_prediction,label='Predict')
sns.lineplot(data=future_prediction_df[-90:], x=future_index[:90], y=future_prediction_df['Price'][-90:],label='Predict next 90 days')
sns.lineplot(data=next60days_df, x=next60days_index, y=next60days_df['Price'],label='Predict next 60 days')
sns.lineplot(data=next30days_df, x=next30days_index, y=next30days_df['Price'],label='Predict next 30 days')
plt.title('Ethereum Time Series Forecasting')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # 9. BNB/USD Dataset (Data split 9:1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Dataset/BNB_USD-Binance-Historical-Data_New.csv')
df = df.sort_index(ascending=False)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)
df = df[['Price']]

# %%
train_size = int(0.9 * len(df))
test_size = len(df) - train_size
train_data = df[:train_size]
test_data = df[train_size:]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def test_stationarity(variable):
    result=adfuller(variable)
    labels = ['t-statistics', 'p-value', 'lags_used', 'number of observations used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Data is stationary")
    else:
        print("Data is non-stationary ")

# %%
test_stationarity(train_data['Price'])
# Out:
# t-statistics : -1.8281963679479987
# p-value : 0.3665555354715905
# lags_used : 25
# number of observations used : 1702
# Data is non-stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['Price'])
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11088\220069074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['First Difference'] = train_data['Price'] - train_data['Price'].shift(1)

# %%
test_stationarity(train_data['First Difference'].dropna())
# Out:
# t-statistics : -7.750700320464524
# p-value : 1.0038502521783725e-11
# lags_used : 24
# number of observations used : 1702
# Data is stationary

# %%
sns.lineplot(data = train_data, x = train_data.index, y = train_data['First Difference'])
# Out:
# <Axes: xlabel='Date', ylabel='First Difference'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_pacf(train_data['First Difference'].dropna(),lags=20)

# %%
plot_acf(train_data['First Difference'].dropna(),lags=20)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(train_data['Price'], order = (5,1,2))
model_fit = model.fit()
model_fit.summary()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1728
# Model:                 ARIMA(5, 1, 2)   Log Likelihood               -6894.172
# Date:                Wed, 05 Jun 2024   AIC                          13804.344
# Time:                        11:24:59   BIC                          13847.978
# Sample:                    03-01-2019   HQIC                         13820.485
#                          - 11-22-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6503      0.114     -5.684      0.000      -0.875      -0.426
# ar.L2         -0.3217      0.095     -3.370      0.001      -0.509      -0.135
# ar.L3          0.0600      0.018      3.400      0.001       0.025       0.095
# ar.L4          0.0680      0.021      3.232      0.001       0.027       0.109
# ar.L5         -0.0815      0.018     -4.482      0.000      -0.117      -0.046
# ma.L1          0.5185      0.115      4.525      0.000       0.294       0.743
# ma.L2          0.3362      0.081      4.135      0.000       0.177       0.496
# sigma2       171.7526      1.825     94.092      0.000     168.175     175.330
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             55626.08
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):              73.73   Skew:                            -0.57
# Prob(H) (two-sided):                  0.00   Kurtosis:                        30.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_prediction = model_fit.forecast(steps=len(test_data))
frame = {'Price':test_prediction[0:]}
test_prediction_df = pd.DataFrame(frame)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
y_test = np.array(test_data['Price'])
y_pred = np.array(test_prediction_df['Price'])

mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print("MAPE:", mape )
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# MAPE: 38.67248914693399
# RMSE: 242.194925558767
# MAE: 195.644047465343

# %%
last_date = df.index[-1]
future_index = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=90)

# %%
future_prediction = model_fit.forecast(steps=len(test_data)+90)

# %%
frame = {'Price':future_prediction[0:]}
future_prediction_df = pd.DataFrame(frame)

# %%
next60days_df = future_prediction_df[-90:]
next60days_df = next60days_df[:60]
next60days_index = future_index[-90:]
next60days_index = next60days_index[:60]

next30days_df = future_prediction_df[-90:]
next30days_df = next30days_df[:30]
next30days_index = future_index[-90:]
next30days_index = next30days_index[:30]

# %%
sns.lineplot(data=train_data, x=train_data.index, y=train_data['Price'],label='Train')
sns.lineplot(data=test_data, x=test_data.index, y=test_data['Price'],label='Test')
sns.lineplot(data=test_data, x=test_data.index, y=test_prediction,label='Predict')
sns.lineplot(data=future_prediction_df[-90:], x=future_index[:90], y=future_prediction_df['Price'][-90:],label='Predict next 90 days')
sns.lineplot(data=next60days_df, x=next60days_index, y=next60days_df['Price'],label='Predict next 60 days')
sns.lineplot(data=next30days_df, x=next30days_index, y=next30days_df['Price'],label='Predict next 30 days')
plt.title('BNB Time Series Forecasting')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')
